# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading and reading the dataset
df=pd.read_csv("https://raw.githubusercontent.com/WidhyaOrg/datasets/master/bitcoin_dataset.csv")
df.head()
# Out:
#         Date  btc_market_price  btc_total_bitcoins  btc_market_cap  \
# 0  2/17/2010               0.0           2043200.0             0.0
# 1  2/18/2010               0.0           2054650.0             0.0
# 2  2/19/2010               0.0           2063600.0             0.0
# 3  2/20/2010               0.0           2074700.0             0.0
# 4  2/21/2010               0.0           2085400.0             0.0
#
#    btc_trade_volume  btc_blocks_size  btc_avg_block_size  \
# 0               0.0              0.0            0.000235
# 1               0.0              0.0            0.000241
# 2               0.0              0.0            0.000228
# 3               0.0              0.0            0.000218
# 4               0.0              0.0            0.000234
#
#    btc_n_orphaned_blocks  btc_n_transactions_per_block  \
# 0                      0                           1.0
# 1                      0                           1.0
# ...

# %%
df["btc_market_price"][1023]
# Out:
# 13.6888

# %%
df.corr()
# Out:
#                                                     btc_market_price  \
# btc_market_price                                            1.000000
# btc_total_bitcoins                                          0.392474
# btc_market_cap                                              0.999783
# btc_trade_volume                                            0.868813
# btc_blocks_size                                             0.674507
# btc_avg_block_size                                          0.544033
# btc_n_orphaned_blocks                                      -0.076400
# btc_n_transactions_per_block                                0.544125
# btc_median_confirmation_time                                0.275250
# btc_hash_rate                                               0.920876
# btc_difficulty                                              0.916937
# btc_miners_revenue                                          0.986732
# btc_transaction_fees                                        0.806595
# ...

# %%
sns.jointplot(data=df,x= "btc_market_price",y= "btc_market_cap")

# %%
#Cleaning Data
df.isnull().sum()
# Out:
# Date                                                    0
# btc_market_price                                        0
# btc_total_bitcoins                                     27
# btc_market_cap                                          0
# btc_trade_volume                                       21
# btc_blocks_size                                        29
# btc_avg_block_size                                      0
# btc_n_orphaned_blocks                                   0
# btc_n_transactions_per_block                            0
# btc_median_confirmation_time                           12
# btc_hash_rate                                           0
# btc_difficulty                                         16
# btc_miners_revenue                                      0
# btc_transaction_fees                                   10
# btc_cost_per_transaction_percent                        0
# btc_cost_per_transaction                                0
# ...

# %%
#filling all null values with the mean values
df["btc_total_bitcoins"].fillna(df["btc_total_bitcoins"].mean(skipna=True),inplace=True)
df["btc_trade_volume"].fillna(df["btc_trade_volume"].mean(skipna=True),inplace=True)
df["btc_blocks_size"].fillna(df["btc_blocks_size"].mean(skipna=True),inplace=True)
df["btc_median_confirmation_time"].fillna(df["btc_median_confirmation_time"].mean(skipna=True),inplace=True)
df["btc_difficulty"].fillna(df["btc_difficulty"].mean(skipna=True),inplace=True)
df["btc_transaction_fees"].fillna(df["btc_transaction_fees"].mean(skipna=True),inplace=True)

# %%
df.isnull().sum()
# Out:
# Date                                                   0
# btc_market_price                                       0
# btc_total_bitcoins                                     0
# btc_market_cap                                         0
# btc_trade_volume                                       0
# btc_blocks_size                                        0
# btc_avg_block_size                                     0
# btc_n_orphaned_blocks                                  0
# btc_n_transactions_per_block                           0
# btc_median_confirmation_time                           0
# btc_hash_rate                                          0
# btc_difficulty                                         0
# btc_miners_revenue                                     0
# btc_transaction_fees                                   0
# btc_cost_per_transaction_percent                       0
# btc_cost_per_transaction                               0
# ...

# %%
df.isnull().values.any()
# Out:
# False

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import mean_squared_error

# %%
x=df[['btc_market_cap','btc_n_transactions','btc_miners_revenue',
          'btc_cost_per_transaction','btc_difficulty','btc_hash_rate','btc_cost_per_transaction_percent']]
y=df['btc_market_price']

# %%
#Split data into train and test
X_train,x_test,Y_train,y_test = train_test_split(x,y,test_size=0.25, random_state= 1)

# %%
#Prediction using Linear regression
lr = LinearRegression()
lr.fit(X_train,Y_train)
Y_pred = lr.predict(x_test)
pred = pd.DataFrame({"Actual Price":y_test ,"Predicted price":Y_pred})
pred
# Out:
#       Actual Price  Predicted price
# 1482    621.990000       590.633152
# 1145    160.099700       145.086851
# 2662   2446.142414      2430.326291
# 432       1.701000        11.573838
# 2264    447.170000       461.943974
# ...            ...              ...
# 579       5.600000        11.052586
# 124       0.000000       -12.738291
# 1781    302.330000       299.116485
# 338       0.440000         1.217029
# 2420    611.851100       629.268229
#
# [727 rows x 2 columns]

# %%
mse= mean_squared_error(y_test,Y_pred)
mse
# Out:
# 474.5121546775459
